# %%
import pandas as pd
df = pd.read_csv('../data/traffic_accidents.csv')
df
# Out:
#               crash_date traffic_control_device weather_condition  \
# 0        7/29/2023 13:00         TRAFFIC SIGNAL             CLEAR
# 1         8/13/2023 0:11         TRAFFIC SIGNAL             CLEAR
# 2        12/9/2021 10:30         TRAFFIC SIGNAL             CLEAR
# 3         8/9/2023 19:55         TRAFFIC SIGNAL             CLEAR
# 4        8/19/2023 14:55         TRAFFIC SIGNAL             CLEAR
# ...                  ...                    ...               ...
# 209301   9/13/2023 13:08                UNKNOWN           UNKNOWN
# 209302   7/18/2023 14:10                UNKNOWN             CLEAR
# 209303  10/23/2019 13:32         TRAFFIC SIGNAL             CLEAR
# 209304    6/1/2020 15:23            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df.isnull().sum()
# Out:
# crash_date                       0
# traffic_control_device           0
# weather_condition                0
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_injury      0
# damage                           0
# prim_contributory_cause          0
# num_units                        0
# most_severe_injury               0
# injuries_total                   0
# injuries_fatal                   0
# injuries_incapacitating          0
# injuries_non_incapacitating      0
# injuries_reported_not_evident    0
# injuries_no_indication           0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# dtype: int64

# %%
df[['traffic_control_device']].describe()
# Out:
#        traffic_control_device
# count                  209306
# unique                     19
# top            TRAFFIC SIGNAL
# freq                   123944

# %%
df[['weather_condition']].describe()
# Out:
#        weather_condition
# count             209306
# unique                12
# top                CLEAR
# freq              164700

# %%
df[['lighting_condition']].describe()
# Out:
#        lighting_condition
# count              209306
# unique                  6
# top              DAYLIGHT
# freq               134109

# %%
df[['first_crash_type']].describe()
# Out:
#        first_crash_type
# count            209306
# unique               18
# top             TURNING
# freq              64157

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df
# Out:
#               crash_date traffic_control_device weather_condition  \
# 0        7/29/2023 13:00         TRAFFIC SIGNAL             CLEAR
# 1         8/13/2023 0:11         TRAFFIC SIGNAL             CLEAR
# 2        12/9/2021 10:30         TRAFFIC SIGNAL             CLEAR
# 3         8/9/2023 19:55         TRAFFIC SIGNAL             CLEAR
# 4        8/19/2023 14:55         TRAFFIC SIGNAL             CLEAR
# ...                  ...                    ...               ...
# 209301   9/13/2023 13:08                UNKNOWN           UNKNOWN
# 209302   7/18/2023 14:10                UNKNOWN             CLEAR
# 209303  10/23/2019 13:32         TRAFFIC SIGNAL             CLEAR
# 209304    6/1/2020 15:23            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df = df.drop(['crash_date'], axis = 1)
df
# Out:
#        traffic_control_device weather_condition      lighting_condition  \
# 0              TRAFFIC SIGNAL             CLEAR                DAYLIGHT
# 1              TRAFFIC SIGNAL             CLEAR  DARKNESS, LIGHTED ROAD
# 2              TRAFFIC SIGNAL             CLEAR                DAYLIGHT
# 3              TRAFFIC SIGNAL             CLEAR                DAYLIGHT
# 4              TRAFFIC SIGNAL             CLEAR                DAYLIGHT
# ...                       ...               ...                     ...
# 209301                UNKNOWN           UNKNOWN                 UNKNOWN
# 209302                UNKNOWN             CLEAR                DAYLIGHT
# 209303         TRAFFIC SIGNAL             CLEAR                DAYLIGHT
# 209304            NO CONTROLS             CLEAR                DAYLIGHT
# 209305         TRAFFIC SIGNAL             CLEAR                DAYLIGHT
#
#                 first_crash_type                  trafficway_type  \
# ...

# %%
df['traffic_control_device'].unique()
# Out:
# array(['TRAFFIC SIGNAL', 'NO CONTROLS', 'STOP SIGN/FLASHER', 'UNKNOWN',
#        'OTHER', 'PEDESTRIAN CROSSING SIGN', 'OTHER WARNING SIGN', 'YIELD',
#        'FLASHING CONTROL SIGNAL', 'LANE USE MARKING', 'OTHER REG. SIGN',
#        'DELINEATORS', 'SCHOOL ZONE', 'POLICE/FLAGMAN', 'NO PASSING',
#        'RR CROSSING SIGN', 'RAILROAD CROSSING GATE',
#        'BICYCLE CROSSING SIGN', 'OTHER RAILROAD CROSSING'], dtype=object)

# %%
df['weather_condition'].unique()
# Out:
# array(['CLEAR', 'RAIN', 'SNOW', 'CLOUDY/OVERCAST', 'UNKNOWN',
#        'FOG/SMOKE/HAZE', 'BLOWING SNOW', 'FREEZING RAIN/DRIZZLE', 'OTHER',
#        'SLEET/HAIL', 'SEVERE CROSS WIND GATE', 'BLOWING SAND, SOIL, DIRT'],
#       dtype=object)

# %%
df['lighting_condition'].unique()
# Out:
# array(['DAYLIGHT', 'DARKNESS, LIGHTED ROAD', 'DUSK', 'DARKNESS',
#        'UNKNOWN', 'DAWN'], dtype=object)

# %%
df['first_crash_type'].unique()
# Out:
# array(['TURNING', 'REAR END', 'ANGLE', 'FIXED OBJECT', 'REAR TO FRONT',
#        'SIDESWIPE SAME DIRECTION', 'SIDESWIPE OPPOSITE DIRECTION',
#        'PEDALCYCLIST', 'PEDESTRIAN', 'HEAD ON', 'PARKED MOTOR VEHICLE',
#        'OTHER NONCOLLISION', 'OVERTURNED', 'OTHER OBJECT', 'REAR TO SIDE',
#        'ANIMAL', 'TRAIN', 'REAR TO REAR'], dtype=object)

# %%
df['trafficway_type'].unique()
# Out:
# array(['NOT DIVIDED', 'FOUR WAY', 'T-INTERSECTION',
#        'DIVIDED - W/MEDIAN (NOT RAISED)', 'OTHER',
#        'UNKNOWN INTERSECTION TYPE', 'ONE-WAY', 'RAMP', 'TRAFFIC ROUTE',
#        'FIVE POINT, OR MORE', 'DIVIDED - W/MEDIAN BARRIER', 'UNKNOWN',
#        'ALLEY', 'CENTER TURN LANE', 'L-INTERSECTION', 'DRIVEWAY',
#        'Y-INTERSECTION', 'PARKING LOT', 'ROUNDABOUT', 'NOT REPORTED'],
#       dtype=object)

# %%
df['alignment'].unique()
# Out:
# array(['STRAIGHT AND LEVEL', 'CURVE, LEVEL', 'STRAIGHT ON HILLCREST',
#        'STRAIGHT ON GRADE', 'CURVE ON GRADE', 'CURVE ON HILLCREST'],
#       dtype=object)

# %%
df['roadway_surface_cond'].unique()
# Out:
# array(['UNKNOWN', 'DRY', 'WET', 'SNOW OR SLUSH', 'ICE', 'OTHER',
#        'SAND, MUD, DIRT'], dtype=object)

# %%
df['road_defect'].unique()
# Out:
# array(['UNKNOWN', 'NO DEFECTS', 'OTHER', 'SHOULDER DEFECT',
#        'WORN SURFACE', 'DEBRIS ON ROADWAY', 'RUT, HOLES'], dtype=object)

# %%
df['crash_type'].unique()
# Out:
# array(['NO INJURY / DRIVE AWAY', 'INJURY AND / OR TOW DUE TO CRASH'],
#       dtype=object)

# %%
df['most_severe_injury'].unique()
# Out:
# array(['NO INDICATION OF INJURY', 'NONINCAPACITATING INJURY',
#        'INCAPACITATING INJURY', 'REPORTED, NOT EVIDENT', 'FATAL'],
#       dtype=object)

# %%
df['prim_contributory_cause'].unique()
# Out:
# array(['UNABLE TO DETERMINE', 'IMPROPER TURNING/NO SIGNAL',
#        'FOLLOWING TOO CLOSELY', 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#        'IMPROPER BACKING', 'FAILING TO YIELD RIGHT-OF-WAY',
#        'IMPROPER OVERTAKING/PASSING', 'DRIVING ON WRONG SIDE/WRONG WAY',
#        'IMPROPER LANE USAGE', 'NOT APPLICABLE',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'DISREGARDING TRAFFIC SIGNALS', 'WEATHER',
#        'DISREGARDING STOP SIGN', 'EQUIPMENT - VEHICLE CONDITION',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'TURNING RIGHT ON RED',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS',
#        'DISREGARDING ROAD MARKINGS',
# ...

# %%
df['prim_contributory_cause'].unique()
# Out:
# array(['UNABLE TO DETERMINE', 'IMPROPER TURNING/NO SIGNAL',
#        'FOLLOWING TOO CLOSELY', 'DRIVING SKILLS/KNOWLEDGE/EXPERIENCE',
#        'IMPROPER BACKING', 'FAILING TO YIELD RIGHT-OF-WAY',
#        'IMPROPER OVERTAKING/PASSING', 'DRIVING ON WRONG SIDE/WRONG WAY',
#        'IMPROPER LANE USAGE', 'NOT APPLICABLE',
#        'FAILING TO REDUCE SPEED TO AVOID CRASH',
#        'DISREGARDING TRAFFIC SIGNALS', 'WEATHER',
#        'DISREGARDING STOP SIGN', 'EQUIPMENT - VEHICLE CONDITION',
#        'OPERATING VEHICLE IN ERRATIC, RECKLESS, CARELESS, NEGLIGENT OR AGGRESSIVE MANNER',
#        'DISREGARDING OTHER TRAFFIC SIGNS', 'TURNING RIGHT ON RED',
#        'VISION OBSCURED (SIGNS, TREE LIMBS, BUILDINGS, ETC.)',
#        'EVASIVE ACTION DUE TO ANIMAL, OBJECT, NONMOTORIST',
#        'UNDER THE INFLUENCE OF ALCOHOL/DRUGS (USE WHEN ARREST IS EFFECTED)',
#        'DISTRACTION - FROM OUTSIDE VEHICLE',
#        'EXCEEDING SAFE SPEED FOR CONDITIONS',
#        'DISREGARDING ROAD MARKINGS',
# ...

# %%
df['damage'].unique()
# Out:
# array(['$501 - $1,500', 'OVER $1,500', '$500 OR LESS'], dtype=object)

# %%
df[['prim_contributory_cause']].describe()
# Out:
#        prim_contributory_cause
# count                   209306
# unique                      40
# top        UNABLE TO DETERMINE
# freq                     58316

# %%
pip install pymysql
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install mysql-connector-python
# Out:
# ...
#
#   Obtaining dependency information for mysql-connector-python from https://files.pythonhosted.org/packages/15/9c/127f974ca9d5ee25373cb5433da06bb1f36e05f2a6b7436da1fe9c6346b0/mysql_connector_python-9.4.0-cp311-cp311-win_amd64.whl.metadata
# ...
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB ? eta -:--:--
#    ---------------------------------------- 0.0/16.4 MB 495.5 kB/s eta 0:00:34
#    ---------------------------------------- 0.1/16.4 MB 845.5 kB/s eta 0:00:20
#    ---------------------------------------- 0.2/16.4 MB 984.6 kB/s eta 0:00:17
#     --------------------------------------- 0.3/16.4 MB 1.7 MB/s eta 0:00:10
#    - -------------------------------------- 0.6/16.4 MB 2.3 MB/s eta 0:00:08
#    -- ------------------------------------- 0.9/16.4 MB 2.9 MB/s eta 0:00:06
#    -- ------------------------------------- 1.1/16.4 MB 3.3 MB/s eta 0:00:05
# ...

# %%
import mysql.connector

# Connect to the database
conn = mysql.connector.connect(
    host="localhost",       # Database host
    user="root",            # Database username
    password="", # Database password
    database="city-traffic-and-accident-pattern-analysis"  # Database name
)

# Create a cursor
cursor = conn.cursor()

# Run a query
cursor.execute("SELECT crash_day_of_week, COUNT(*) FROM traffic_accidents GROUP BY crash_day_of_week ORDER BY crash_day_of_week;")

# Fetch results
for row in cursor.fetchall():
    print(row)

# Close connection
cursor.close()
# Create a cursor
cursor = conn.cursor()

# Run a query
cursor.execute("SELECT * FROM traffic_accidents")

# Fetch results
row = cursor.fetchall()
DF = pd.DataFrame(row)
# Close connection
cursor.close()
conn.close()
DF
# Out:
# (1, 25246)
# (2, 27938)
# (3, 30074)
# (4, 30093)
# (5, 30787)
# (6, 34458)
# (7, 30710)
#                       0               1        2                       3   \
# 0        7/29/2023 13:00  TRAFFIC SIGNAL    CLEAR                DAYLIGHT
# 1         8/13/2023 0:11  TRAFFIC SIGNAL    CLEAR  DARKNESS, LIGHTED ROAD
# 2        12/9/2021 10:30  TRAFFIC SIGNAL    CLEAR                DAYLIGHT
# 3         8/9/2023 19:55  TRAFFIC SIGNAL    CLEAR                DAYLIGHT
# 4        8/19/2023 14:55  TRAFFIC SIGNAL    CLEAR                DAYLIGHT
# ...                  ...             ...      ...                     ...
# 209301   9/13/2023 13:08         UNKNOWN  UNKNOWN                 UNKNOWN
# 209302   7/18/2023 14:10         UNKNOWN    CLEAR                DAYLIGHT
# 209303  10/23/2019 13:32  TRAFFIC SIGNAL    CLEAR                DAYLIGHT
# 209304    6/1/2020 15:23     NO CONTROLS    CLEAR                DAYLIGHT
# ...

# %%
dictionary={0: "crash_date", 1: "traffic_control_device", 2:"weather_condition",3:"lighting_condition",4:"first_crash_type",5:"trafficway_type",6:"alignment",7:"roadway_surface_cond",8:"road_defect",9:"crash_type",10:"intersection_related_injury",11:"damage",12:"prim_contributory_cause",13:"num_units",14:"most_severe_injury",15:"injuries_total",16:"injuries_fatal",17:"injuries_incapacitating",18:"injuries_non_incapacitating",19:"injuries_reported_not_evident",20:"injuries_no_indication",21:"crash_hour",22:"crash_day_of_week",23:"crash_month"}
DF.rename(columns = dictionary, inplace = True)

# %%
DF
# Out:
#               crash_date traffic_control_device weather_condition  \
# 0        7/29/2023 13:00         TRAFFIC SIGNAL             CLEAR
# 1         8/13/2023 0:11         TRAFFIC SIGNAL             CLEAR
# 2        12/9/2021 10:30         TRAFFIC SIGNAL             CLEAR
# 3         8/9/2023 19:55         TRAFFIC SIGNAL             CLEAR
# 4        8/19/2023 14:55         TRAFFIC SIGNAL             CLEAR
# ...                  ...                    ...               ...
# 209301   9/13/2023 13:08                UNKNOWN           UNKNOWN
# 209302   7/18/2023 14:10                UNKNOWN             CLEAR
# 209303  10/23/2019 13:32         TRAFFIC SIGNAL             CLEAR
# 209304    6/1/2020 15:23            NO CONTROLS             CLEAR
# 209305  12/16/2022 12:10         TRAFFIC SIGNAL             CLEAR
#
#             lighting_condition          first_crash_type  \
# 0                     DAYLIGHT                   TURNING
# ...

# %%
df.isnull().sum()
# Out:
# crash_date                       0
# traffic_control_device           0
# weather_condition                0
# lighting_condition               0
# first_crash_type                 0
# trafficway_type                  0
# alignment                        0
# roadway_surface_cond             0
# road_defect                      0
# crash_type                       0
# intersection_related_injury      0
# damage                           0
# prim_contributory_cause          0
# num_units                        0
# most_severe_injury               0
# injuries_total                   0
# injuries_fatal                   0
# injuries_incapacitating          0
# injuries_non_incapacitating      0
# injuries_reported_not_evident    0
# injuries_no_indication           0
# crash_hour                       0
# crash_day_of_week                0
# crash_month                      0
# dtype: int64
